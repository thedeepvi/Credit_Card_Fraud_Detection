# %% [markdown]
# # Data Loading

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('cred.csv')

# %%
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %% [markdown]
# # Data Exploration

# %% [markdown]
# The data contains 284807 number of rows and 31 number of columns. The row represents the transaction. The column represents the features of each transaction

# %%
print('Number of Transactions: {}'.format(data.shape[0]))
print('Number of Features: {}'.format(data.shape[1]))
# Out:
# Number of Transactions: 284807
# Number of Features: 31

# %% [markdown]
# Here are the name of all columns. Three columns have understandable name including Time, Amount, and Class. Remaining twenty eight features are kept sectrate and represents secure credential of each transaction.

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %% [markdown]
# Here is the sample of first five transactions

# %%
data.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# Here are the last five transactions

# %%
data.tail(5)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [5 rows x 31 columns]

# %% [markdown]
# Here is the counting record of all missing or undefined values in each column

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# Here is the statistical values of the data.

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.473120e-16  8.042109e-16  5.282512e-16  4.456271e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.426896e-15  1.701640e-15 -3.662252e-16 -1.217809e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# The data contians authentic transactions and fraudulent transactions. Authentic transactions are represented by 0 and fraudulent transactions are represeted by 1. Here is totoal count of authentic and fraudulent transactions and ratio. The ratio describe the period of fraudulent transaction.

# %% [markdown]
# # Exploratory Data Analysis

# %%
class_size = data['Class'].value_counts()
print('Number of Authentic Transactions: {}'.format(class_size[0]))
print('Number of Fraudulent Transactions: {}'.format(class_size[1]))
print('Ratio of Authentic to Fraudulent: {}'.format(int(class_size[0]/class_size[1])))
# Out:
# Number of Authentic Transactions: 284315
# Number of Fraudulent Transactions: 492
# Ratio of Authentic to Fraudulent: 577

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.subplot(121)
plt.pie(x = data.groupby(['Class']).Class.count().to_list(),
        labels = ["Left", "Right"], autopct='%1.2f%%', explode = (0, 0.2))

plt.subplot(122)
sns.countplot(data = data, x = 'Class')
fraudnt, fraud = data.Class.value_counts()
plt.text(0, fraudnt//2, fraudnt, fontsize = 20,  horizontalalignment='center')
plt.text(1, fraud//2, fraud, fontsize = 20, horizontalalignment='center')
# Out:
# Text(1, 246, '492')

# %% [markdown]
# # Observation
# Using such an imbalanced dataset for machine learning can lead to very poor performance in real life. We will see some ways that we can mitigate this issue later in this notebook.

# %% [markdown]
# The correlation matrix defines the dependencies of each feature on other features

# %%
import seaborn as sns
sns.heatmap(data.corr(), cmap='coolwarm_r', vmin = -1, vmax = 1, center = 0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #Looks like no feature is correlated, but this is the result of the highly imbalanced nature of the dataset, taking a subset of the dataset will give us a clearer picture.

# %%
fraud_df = data.loc[data['Class'] == 1]
non_fraud_df = data.loc[data['Class'] == 0][:492]
sub_df = pd.concat([fraud_df, non_fraud_df]).sample(frac=1, random_state=420).reset_index(drop=True)
sns.heatmap(sub_df.corr(), cmap='coolwarm_r', vmin = -1, vmax = 1, center = 0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# This is much better at telling us the true correlation between the features.

# %% [markdown]
# # Data Preparation

# %%
data = data.sample(frac=1)

# amount of fraud classes 492 rows.
fraud_df = data.loc[data['Class'] == 1]
non_fraud_df = data.loc[data['Class'] == 0][:492]

normal_distributed_df = pd.concat([fraud_df, non_fraud_df])

# Shuffle dataframe rows
data = normal_distributed_df.sample(frac=1, random_state=42)

data.head()
# Out:
#             Time         V1         V2         V3        V4         V5  \
# 280553  169601.0  -0.867904   0.819422   1.656226  2.432648   1.035631
# 43681    41607.0 -18.247513   8.713250 -17.880127  9.249459 -14.541213
# 232126  147054.0  -0.578175   0.234103   1.460924  1.198952  -0.412668
# 151009   94362.0 -26.457745  16.497472 -30.177317  8.904157 -17.892600
# 141258   84204.0  -0.937843   3.462889  -6.445104  4.932199  -2.233983
#
#               V6         V7         V8        V9  ...       V21       V22  \
# 280553  2.670818  -0.047517   0.464108 -0.505749  ...  0.153480  0.647135
# 43681  -1.911564 -18.014660   5.522162 -9.283925  ...  0.598843  0.615319
# 232126  2.064715  -1.431815  -2.165361  0.031089  ... -1.403650 -0.140704
# 151009 -1.227904 -31.197329 -11.438920 -9.462573  ... -8.755698  3.460893
# 141258 -2.291561  -5.695594   1.338825 -4.322377  ...  1.066550 -0.521657
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 280553  0.201767 -1.697482 -0.971697 -0.226239 -0.621452 -0.201013   20.47
# 43681  -0.486499  0.739268 -0.236845 -0.046082 -3.011473 -1.022147   53.95
# 232126 -0.399667  0.181595  1.368715 -0.437460  0.067478  0.209832  153.42
# 151009  0.896538  0.254836 -0.738097 -0.966564 -7.263482 -1.324884    1.00
# 141258 -0.319917 -0.405859  0.906802  1.165784  1.374495  0.729889    0.00
#
#         Class
# 280553      0
# 43681       1
# 232126      0
# 151009      1
# 141258      1
#
# [5 rows x 31 columns]

# %% [markdown]
# # After undersampling of data

# %%
import matplotlib.pyplot as plt
plt.subplot(121)
plt.pie(x = data.groupby(['Class']).Class.count().to_list(),
        labels = ["Left", "Right"], autopct='%1.2f%%', explode = (0, 0.2))

plt.subplot(122)
sns.countplot(data = data, x = 'Class')
fraudnt, fraud = data.Class.value_counts()
plt.text(0, fraudnt//2, fraudnt, fontsize = 20,  horizontalalignment='center')
plt.text(1, fraud//2, fraud, fontsize = 20, horizontalalignment='center')
# Out:
# Text(1, 246, '492')

# %% [markdown]
# The scaling is the process of maping values in a well defined interval. We use MinMaxScaler which use minimum and maxmim value of each feature and maps accordinlgy other values

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data['Amount'] = scaler.fit_transform(data['Amount'].values.reshape(-1,1))
data
# Out:
#             Time         V1         V2         V3         V4         V5  \
# 280553  169601.0  -0.867904   0.819422   1.656226   2.432648   1.035631
# 43681    41607.0 -18.247513   8.713250 -17.880127   9.249459 -14.541213
# 232126  147054.0  -0.578175   0.234103   1.460924   1.198952  -0.412668
# 151009   94362.0 -26.457745  16.497472 -30.177317   8.904157 -17.892600
# 141258   84204.0  -0.937843   3.462889  -6.445104   4.932199  -2.233983
# ...          ...        ...        ...        ...        ...        ...
# 10891    18675.0 -12.339603   4.488267 -16.587073  10.107274 -10.420199
# 69980    53658.0  -1.739341   1.344521  -0.534379   3.195291  -0.416196
# 2233      1758.0   1.118282  -0.376211   1.068760   0.635106  -0.820696
# 79536    58067.0  -0.264869   3.386140  -3.454997   4.367629   3.336060
# 156988  109297.0   0.745153   2.809299  -5.825406   5.835566   0.512320
#
#               V6         V7         V8        V9  ...       V21       V22  \
# 280553  2.670818  -0.047517   0.464108 -0.505749  ...  0.153480  0.647135
# 43681  -1.911564 -18.014660   5.522162 -9.283925  ...  0.598843  0.615319
# 232126  2.064715  -1.431815  -2.165361  0.031089  ... -1.403650 -0.140704
# 151009 -1.227904 -31.197329 -11.438920 -9.462573  ... -8.755698  3.460893
# 141258 -2.291561  -5.695594   1.338825 -4.322377  ...  1.066550 -0.521657
# ...          ...        ...        ...       ...  ...       ...       ...
# 10891   0.130670 -15.600323  -1.157696 -5.304631  ... -2.089610  1.745315
# 69980  -1.261961  -2.340991   0.713004 -1.416265  ...  0.383180 -0.213952
# 2233    0.643828  -0.916168   0.466360  0.919572  ... -0.051761 -0.027883
# 79536  -2.053918   0.256890  -2.957235 -2.855797  ... -1.394504 -0.166029
# 156988 -0.615622  -2.916576   0.776710 -1.878832  ...  0.284841 -0.874383
#
#              V23       V24       V25       V26       V27       V28    Amount  \
# 280553  0.201767 -1.697482 -0.971697 -0.226239 -0.621452 -0.201013  0.002654
# 43681  -0.486499  0.739268 -0.236845 -0.046082 -3.011473 -1.022147  0.006995
# 232126 -0.399667  0.181595  1.368715 -0.437460  0.067478  0.209832  0.019893
# 151009  0.896538  0.254836 -0.738097 -0.966564 -7.263482 -1.324884  0.000130
# 141258 -0.319917 -0.405859  0.906802  1.165784  1.374495  0.729889  0.000000
# ...          ...       ...       ...       ...       ...       ...       ...
# 10891   1.376816 -0.554271 -1.610741  0.153725  1.212477 -1.869290  0.024477
# 69980  -0.336640  0.237076  0.246003 -0.044228  0.510729  0.220952  0.000000
# 2233    0.026693 -0.301207  0.144229  0.354133  0.019286  0.007082  0.001101
# 79536  -1.452081 -0.251815  1.243461  0.452787  0.132218  0.424599  0.000130
# 156988 -0.083995 -0.651442  0.454594  0.050376  0.756953  0.383869  0.000000
#
#         Class
# 280553      0
# 43681       1
# 232126      0
# 151009      1
# 141258      1
# ...       ...
# 10891       1
# 69980       1
# 2233        0
# 79536       1
# 156988      1
#
# [984 rows x 31 columns]

# %% [markdown]
# The data may contain missing or undefined values. This may cause training erro while training the model. So by using dataframe dropna function we are removing all these transactions.

# %%
data.dropna()
# Out:
#             Time         V1         V2         V3         V4         V5  \
# 280553  169601.0  -0.867904   0.819422   1.656226   2.432648   1.035631
# 43681    41607.0 -18.247513   8.713250 -17.880127   9.249459 -14.541213
# 232126  147054.0  -0.578175   0.234103   1.460924   1.198952  -0.412668
# 151009   94362.0 -26.457745  16.497472 -30.177317   8.904157 -17.892600
# 141258   84204.0  -0.937843   3.462889  -6.445104   4.932199  -2.233983
# ...          ...        ...        ...        ...        ...        ...
# 10891    18675.0 -12.339603   4.488267 -16.587073  10.107274 -10.420199
# 69980    53658.0  -1.739341   1.344521  -0.534379   3.195291  -0.416196
# 2233      1758.0   1.118282  -0.376211   1.068760   0.635106  -0.820696
# 79536    58067.0  -0.264869   3.386140  -3.454997   4.367629   3.336060
# 156988  109297.0   0.745153   2.809299  -5.825406   5.835566   0.512320
#
#               V6         V7         V8        V9  ...       V21       V22  \
# 280553  2.670818  -0.047517   0.464108 -0.505749  ...  0.153480  0.647135
# 43681  -1.911564 -18.014660   5.522162 -9.283925  ...  0.598843  0.615319
# 232126  2.064715  -1.431815  -2.165361  0.031089  ... -1.403650 -0.140704
# 151009 -1.227904 -31.197329 -11.438920 -9.462573  ... -8.755698  3.460893
# 141258 -2.291561  -5.695594   1.338825 -4.322377  ...  1.066550 -0.521657
# ...          ...        ...        ...       ...  ...       ...       ...
# 10891   0.130670 -15.600323  -1.157696 -5.304631  ... -2.089610  1.745315
# 69980  -1.261961  -2.340991   0.713004 -1.416265  ...  0.383180 -0.213952
# 2233    0.643828  -0.916168   0.466360  0.919572  ... -0.051761 -0.027883
# 79536  -2.053918   0.256890  -2.957235 -2.855797  ... -1.394504 -0.166029
# 156988 -0.615622  -2.916576   0.776710 -1.878832  ...  0.284841 -0.874383
#
#              V23       V24       V25       V26       V27       V28    Amount  \
# 280553  0.201767 -1.697482 -0.971697 -0.226239 -0.621452 -0.201013  0.002654
# 43681  -0.486499  0.739268 -0.236845 -0.046082 -3.011473 -1.022147  0.006995
# 232126 -0.399667  0.181595  1.368715 -0.437460  0.067478  0.209832  0.019893
# 151009  0.896538  0.254836 -0.738097 -0.966564 -7.263482 -1.324884  0.000130
# 141258 -0.319917 -0.405859  0.906802  1.165784  1.374495  0.729889  0.000000
# ...          ...       ...       ...       ...       ...       ...       ...
# 10891   1.376816 -0.554271 -1.610741  0.153725  1.212477 -1.869290  0.024477
# 69980  -0.336640  0.237076  0.246003 -0.044228  0.510729  0.220952  0.000000
# 2233    0.026693 -0.301207  0.144229  0.354133  0.019286  0.007082  0.001101
# 79536  -1.452081 -0.251815  1.243461  0.452787  0.132218  0.424599  0.000130
# 156988 -0.083995 -0.651442  0.454594  0.050376  0.756953  0.383869  0.000000
#
#         Class
# 280553      0
# 43681       1
# 232126      0
# 151009      1
# 141258      1
# ...       ...
# 10891       1
# 69980       1
# 2233        0
# 79536       1
# 156988      1
#
# [984 rows x 31 columns]

# %% [markdown]
# # Modeling

# %% [markdown]
# <b>Data Grouping<b>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data.iloc[:,:-1], data.iloc[:,-1], test_size=0.33, random_state=42)

# %%
X_train
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 275992  166831.0  -2.027135  -1.131890 -1.135194  1.086963 -0.010547
# 70434    53865.0  -0.674000   1.309359 -0.345251  1.684273  2.096352
# 623        472.0  -3.043541  -3.157307  1.088463  2.288644  1.359805
# 80925    58718.0  -0.758114   1.018286  0.999354  1.120647 -0.807101
# 64636    51239.0  -1.634235   0.358171  0.654021 -1.243497 -0.235164
# ...          ...        ...        ...       ...       ...       ...
# 221018  142394.0  -3.367770   0.099249 -6.148487  3.401955  0.458307
# 102445   68207.0 -13.192671  12.785971 -9.906650  3.320337 -4.801176
# 34305    37603.0  -2.595874   1.011564 -2.501576  0.029774  4.295151
# 142405   84694.0  -4.868108   1.264420 -5.167885  3.193648 -3.045621
# 30384    35899.0  -2.857170   4.045601 -4.197299  5.487199 -3.070776
#
#               V6         V7         V8        V9  ...       V20        V21  \
# 275992  0.423797   3.790880  -1.155595 -0.063434  ...  0.033804  -0.315105
# 70434   4.106493  -0.041212   1.394191 -1.776727  ...  0.424239  -0.095588
# 623    -1.064823   0.325574  -0.067794 -0.270953  ...  2.102339   0.661696
# 80925  -0.946778   0.837774   0.208887 -0.850431  ...  0.088001   0.296685
# 64636  -0.730392   0.751913   0.364986 -0.491087  ... -0.163724  -0.139909
# ...          ...        ...        ...       ...  ...       ...        ...
# 221018 -1.571630  -1.358708   0.672409 -3.188001  ...  0.264699   0.861308
# 102445  5.760059 -18.750889 -37.353443 -0.391540  ... -3.493050  27.202839
# 34305   2.248078   0.705500   0.229495 -0.407563  ... -1.085172  -0.414136
# 142405 -2.096166  -6.445610   2.422536 -3.214055  ...  0.667310   1.269205
# 30384  -1.422686  -5.651314   2.019657 -5.015491  ...  0.981609   1.080323
#
#              V22       V23       V24       V25       V26       V27       V28  \
# 275992  0.575520  0.490842  0.756502 -0.142685 -0.602777  0.508712 -0.091646
# 70434  -0.569771  0.177161  0.963550 -0.252239  0.025349  0.247775  0.154562
# 623     0.435477  1.375966 -0.293803  0.279798 -0.145362 -0.252773  0.035764
# 80925   0.556403  0.224925  0.909480 -0.272359 -0.367898  0.007098  0.114751
# 64636  -0.393148  0.569039  0.012804 -0.152946  0.673785  0.104071  0.004687
# ...          ...       ...       ...       ...       ...       ...       ...
# 221018  1.249301  1.850627 -0.117471  1.219815  0.000251  1.036011  0.004367
# 102445 -8.887017  5.303607 -0.639435  0.263203 -0.108877  1.269566  0.939407
# 34305  -0.441845  0.276985  0.703271  0.616191 -0.366977 -0.675731  0.146302
# 142405  0.057657  0.629307 -0.168432  0.443744  0.276539  1.441274 -0.127944
# 30384  -0.561384  0.102678 -0.067195 -0.476931 -0.103716  1.166961  0.663632
#
#           Amount
# 275992  0.082244
# 70434   0.009950
# 623     0.068591
# 80925   0.015755
# 64636   0.015572
# ...          ...
# 221018  0.041493
# 102445  0.000130
# 34305   0.000130
# 142405  0.001596
# 30384   0.000130
#
# [659 rows x 30 columns]

# %% [markdown]
# <b>Models<b>

# %%
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import matthews_corrcoef
from matplotlib import pyplot as plt

# %% [markdown]
# <b>Linear Discriminant Analysis</b>

# %%
# %%time
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc
LDA_model = LinearDiscriminantAnalysis()
y_predi = LDA_model.fit(X_train, y_train)
y_predi=LDA_model.predict(X_test)
a=1-accuracy_score(y_test, y_predi)
# Check accuracy score 
from sklearn.metrics import accuracy_score
print('ACCURACY  =  : {0:0.4f}'. format(accuracy_score(y_test, y_predi)))
print('error = ',a)
from sklearn.metrics import confusion_matrix
import numpy as np
cm= confusion_matrix(y_test, y_predi)

#print(cm)
plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Wistia)
classNames = ['Negative','Positive']
plt.title(' Confusion Matrix - Test Data')
plt.ylabel('True label')
plt.xlabel('Predicted label')
tick_marks = np.arange(len(classNames))
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
s = [['TN','FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        plt.text(j,i, str(s[i][j])+" = "+str(cm[i][j]))
plt.show()

TP = cm[0][0]
FN = cm[0][1]
FP = cm[1][0]
TN = cm[1][1]
TPR=TP/(TP+FN)
TNR=TN/(TN+FP)
print('Sensivity =',TPR)
print('Specificity =',TNR)
### Compute ROC curve and ROC area for predictions on validation set
fpr, tpr, _ = roc_curve(y_test, y_predi)
roc_auc = auc(fpr, tpr)

### Plot
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
print(classification_report(y_test, y_predi))
# Out:
# ACCURACY  =  : 0.8985
# error =  0.10153846153846158
# Sensivity = 1.0
# Specificity = 0.8135593220338984
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90       148
#            1       1.00      0.81      0.90       177
#
#     accuracy                           0.90       325
#    macro avg       0.91      0.91      0.90       325
# weighted avg       0.92      0.90      0.90       325
#
# Wall time: 482 ms

# %% [markdown]
# <b>Logistic Regression</b>

# %%
# %%time
from sklearn.linear_model import LogisticRegression

LG_model = LogisticRegression()
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc
y_predi = LG_model.fit(X_train, y_train)
y_predi=LG_model.predict(X_test)
a=1-accuracy_score(y_test, y_predi)
# Check accuracy score 
from sklearn.metrics import accuracy_score
print('ACCURACY =  : {0:0.4f}'. format(accuracy_score(y_test, y_predi)))
print('error = ',a)
from sklearn.metrics import confusion_matrix
import numpy as np
cm= confusion_matrix(y_test, y_predi)

#print(cm)
plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Wistia)
classNames = ['Negative','Positive']
plt.title(' Confusion Matrix - Test Data')
plt.ylabel('True label')
plt.xlabel('Predicted label')
tick_marks = np.arange(len(classNames))
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
s = [['TN','FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        plt.text(j,i, str(s[i][j])+" = "+str(cm[i][j]))
plt.show()

TP = cm[0][0]
FN = cm[0][1]
FP = cm[1][0]
TN = cm[1][1]
TPR=TP/(TP+FN)
TNR=TN/(TN+FP)
print('Sensivity =',TPR)
print('Specificity =',TNR)
### Compute ROC curve and ROC area for predictions on validation set
fpr, tpr, _ = roc_curve(y_test, y_predi)
roc_auc = auc(fpr, tpr)

### Plot
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
print(classification_report(y_test, y_predi))
# Out:
# ACCURACY =  : 0.9538
# error =  0.0461538461538461
# Sensivity = 0.9864864864864865
# Specificity = 0.9265536723163842
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95       148
#            1       0.99      0.93      0.96       177
#
#     accuracy                           0.95       325
#    macro avg       0.95      0.96      0.95       325
# weighted avg       0.96      0.95      0.95       325
#
# Wall time: 227 ms

# %% [markdown]
# <b>Support Vector Machine</b>

# %%
# %%time
from sklearn.svm import SVC

SVC_model = SVC()

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc
y_predi = SVC_model.fit(X_train, y_train)
y_predi=SVC_model.predict(X_test)
a=1-accuracy_score(y_test, y_predi)
# Check accuracy score 
from sklearn.metrics import accuracy_score
print('ACCURACY  =  : {0:0.4f}'. format(accuracy_score(y_test, y_predi)))
print('error = ',a)
from sklearn.metrics import confusion_matrix
import numpy as np
cm= confusion_matrix(y_test, y_predi)

#print(cm)
plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Wistia)
classNames = ['Negative','Positive']
plt.title(' Confusion Matrix - Test Data')
plt.ylabel('True label')
plt.xlabel('Predicted label')
tick_marks = np.arange(len(classNames))
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
s = [['TN','FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        plt.text(j,i, str(s[i][j])+" = "+str(cm[i][j]))
plt.show()

TP = cm[0][0]
FN = cm[0][1]
FP = cm[1][0]
TN = cm[1][1]
TPR=TP/(TP+FN)
TNR=TN/(TN+FP)
print('Sensivity =',TPR)
print('Specificity =',TNR)
### Compute ROC curve and ROC area for predictions on validation set
fpr, tpr, _ = roc_curve(y_test, y_predi)
roc_auc = auc(fpr, tpr)

### Plot
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
print(classification_report(y_test, y_predi))
# Out:
# ACCURACY  =  : 0.5662
# error =  0.4338461538461539
# Sensivity = 0.7094594594594594
# Specificity = 0.4463276836158192
#               precision    recall  f1-score   support
#
#            0       0.52      0.71      0.60       148
#            1       0.65      0.45      0.53       177
#
#     accuracy                           0.57       325
#    macro avg       0.58      0.58      0.56       325
# weighted avg       0.59      0.57      0.56       325
#
# Wall time: 259 ms

# %% [markdown]
# <b>Naive Bayes (Gaussian)</b>

# %%
# %%time
from sklearn.naive_bayes import GaussianNB

NB_model = GaussianNB()
y_predi = NB_model.fit(X_train, y_train)
y_predi=NB_model.predict(X_test)
a=1-accuracy_score(y_test, y_predi)
# Check accuracy score 
from sklearn.metrics import accuracy_score
print('ACCURACY  =  : {0:0.4f}'. format(accuracy_score(y_test, y_predi)))
print('error  = ',a)
from sklearn.metrics import confusion_matrix
import numpy as np
cm= confusion_matrix(y_test, y_predi)

#print(cm)
plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Wistia)
classNames = ['Negative','Positive']
plt.title(' Confusion Matrix - Test Data')
plt.ylabel('True label')
plt.xlabel('Predicted label')
tick_marks = np.arange(len(classNames))
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
s = [['TN','FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        plt.text(j,i, str(s[i][j])+" = "+str(cm[i][j]))
plt.show()

TP = cm[0][0]
FN = cm[0][1]
FP = cm[1][0]
TN = cm[1][1]
TPR=TP/(TP+FN)
TNR=TN/(TN+FP)
print('Sensivity =',TPR)
print('Specificity =',TNR)
### Compute ROC curve and ROC area for predictions on validation set
fpr, tpr, _ = roc_curve(y_test, y_predi)
roc_auc = auc(fpr, tpr)

### Plot
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
print(classification_report(y_test, y_predi))
# Out:
# ACCURACY  =  : 0.8831
# error  =  0.11692307692307691
# Sensivity = 0.9932432432432432
# Specificity = 0.7909604519774012
#               precision    recall  f1-score   support
#
#            0       0.80      0.99      0.89       148
#            1       0.99      0.79      0.88       177
#
#     accuracy                           0.88       325
#    macro avg       0.90      0.89      0.88       325
# weighted avg       0.90      0.88      0.88       325
#
# Wall time: 211 ms

# %% [markdown]
# <b>K-Nearest Neighbors</b>

# %%
# %%time
from sklearn.neighbors import KNeighborsClassifier

KNN_model = KNeighborsClassifier()
y_predi = KNN_model.fit(X_train, y_train)
y_predi=KNN_model.predict(X_test)
a=1-accuracy_score(y_test, y_predi)
# Check accuracy score 
from sklearn.metrics import accuracy_score
print('ACCURACY  =  : {0:0.4f}'. format(accuracy_score(y_test, y_predi)))
print('error = ',a)
from sklearn.metrics import confusion_matrix
import numpy as np
cm= confusion_matrix(y_test, y_predi)

#print(cm)
plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Wistia)
classNames = ['Negative','Positive']
plt.title(' Confusion Matrix - Test Data')
plt.ylabel('True label')
plt.xlabel('Predicted label')
tick_marks = np.arange(len(classNames))
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
s = [['TN','FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        plt.text(j,i, str(s[i][j])+" = "+str(cm[i][j]))
plt.show()

TP = cm[0][0]
FN = cm[0][1]
FP = cm[1][0]
TN = cm[1][1]
TPR=TP/(TP+FN)
TNR=TN/(TN+FP)
print('Sensivity =',TPR)
print('Specificity =',TNR)
### Compute ROC curve and ROC area for predictions on validation set
fpr, tpr, _ = roc_curve(y_test, y_predi)
roc_auc = auc(fpr, tpr)

### Plot
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
print(classification_report(y_test, y_predi))
# Out:
# ACCURACY  =  : 0.6800
# error =  0.31999999999999995
# Sensivity = 0.7027027027027027
# Specificity = 0.6610169491525424
#               precision    recall  f1-score   support
#
#            0       0.63      0.70      0.67       148
#            1       0.73      0.66      0.69       177
#
#     accuracy                           0.68       325
#    macro avg       0.68      0.68      0.68       325
# weighted avg       0.68      0.68      0.68       325
#
# Wall time: 274 ms

# %% [markdown]
# <b>Decision Tree<b>

# %%
# %%time
from sklearn.tree import DecisionTreeClassifier

DT_model = DecisionTreeClassifier()
y_predi = DT_model.fit(X_train, y_train)
y_predi=DT_model.predict(X_test)
a=1-accuracy_score(y_test, y_predi)
# Check accuracy score 
from sklearn.metrics import accuracy_score
print('ACCURACY  =  : {0:0.4f}'. format(accuracy_score(y_test, y_predi)))
print('error  = ',a)
from sklearn.metrics import confusion_matrix
import numpy as np
cm= confusion_matrix(y_test, y_predi)

#print(cm)
plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Wistia)
classNames = ['Negative','Positive']
plt.title(' Confusion Matrix - Test Data')
plt.ylabel('True label')
plt.xlabel('Predicted label')
tick_marks = np.arange(len(classNames))
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
s = [['TN','FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        plt.text(j,i, str(s[i][j])+" = "+str(cm[i][j]))
plt.show()

TP = cm[0][0]
FN = cm[0][1]
FP = cm[1][0]
TN = cm[1][1]
TPR=TP/(TP+FN)
TNR=TN/(TN+FP)
print('Sensivity =',TPR)
print('Specificity =',TNR)
### Compute ROC curve and ROC area for predictions on validation set
fpr, tpr, _ = roc_curve(y_test, y_predi)
roc_auc = auc(fpr, tpr)

### Plot
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
print(classification_report(y_test, y_predi))
# Out:
# ACCURACY  =  : 0.9077
# error  =  0.09230769230769231
# Sensivity = 0.9054054054054054
# Specificity = 0.9096045197740112
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90       148
#            1       0.92      0.91      0.91       177
#
#     accuracy                           0.91       325
#    macro avg       0.91      0.91      0.91       325
# weighted avg       0.91      0.91      0.91       325
#
# Wall time: 298 ms

# %% [markdown]
# <b>Extreem Gradient Boost<b>

# %%
# %%time
from xgboost import XGBClassifier

XGB_model = XGBClassifier(use_label_encoder=False )
y_predi = XGB_model.fit(X_train, y_train)
y_predi=XGB_model.predict(X_test)
a=1-accuracy_score(y_test, y_predi)
# Check accuracy score 
from sklearn.metrics import accuracy_score
print('ACCURACY =  : {0:0.4f}'. format(accuracy_score(y_test, y_predi)))
print('error = ',a)
from sklearn.metrics import confusion_matrix
import numpy as np
cm= confusion_matrix(y_test, y_predi)

#print(cm)
plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Wistia)
classNames = ['Negative','Positive']
plt.title(' Confusion Matrix - Test Data')
plt.ylabel('True label')
plt.xlabel('Predicted label')
tick_marks = np.arange(len(classNames))
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
s = [['TN','FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        plt.text(j,i, str(s[i][j])+" = "+str(cm[i][j]))
plt.show()

TP = cm[0][0]
FN = cm[0][1]
FP = cm[1][0]
TN = cm[1][1]
TPR=TP/(TP+FN)
TNR=TN/(TN+FP)
print('Sensivity =',TPR)
print('Specificity =',TNR)
### Compute ROC curve and ROC area for predictions on validation set
fpr, tpr, _ = roc_curve(y_test, y_predi)
roc_auc = auc(fpr, tpr)

### Plot
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
print(classification_report(y_test, y_predi))
# Out:
# [14:29:33] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ACCURACY =  : 0.9415
# error =  0.058461538461538454
# Sensivity = 0.972972972972973
# Specificity = 0.9152542372881356
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       148
#            1       0.98      0.92      0.94       177
#
#     accuracy                           0.94       325
#    macro avg       0.94      0.94      0.94       325
# weighted avg       0.94      0.94      0.94       325
#
# Wall time: 389 ms

# %% [markdown]
# <b>Random Forest<b>

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier

RF_model = RandomForestClassifier()
y_predi = RF_model.fit(X_train, y_train)
y_predi=RF_model.predict(X_test)
a=1-accuracy_score(y_test, y_predi)
# Check accuracy score 
from sklearn.metrics import accuracy_score
print('ACCURACY  =  : {0:0.4f}'. format(accuracy_score(y_test, y_predi)))
print('error = ',a)
from sklearn.metrics import confusion_matrix
import numpy as np
cm= confusion_matrix(y_test, y_predi)

#print(cm)
plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Wistia)
classNames = ['Negative','Positive']
plt.title(' Confusion Matrix - Test Data')
plt.ylabel('True label')
plt.xlabel('Predicted label')
tick_marks = np.arange(len(classNames))
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
s = [['TN','FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        plt.text(j,i, str(s[i][j])+" = "+str(cm[i][j]))
plt.show()

TP = cm[0][0]
FN = cm[0][1]
FP = cm[1][0]
TN = cm[1][1]
TPR=TP/(TP+FN)
TNR=TN/(TN+FP)
print('Sensivity =',TPR)
print('Specificity =',TNR)
### Compute ROC curve and ROC area for predictions on validation set
fpr, tpr, _ = roc_curve(y_test, y_predi)
roc_auc = auc(fpr, tpr)

### Plot
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
print(classification_report(y_test, y_predi))
# Out:
# ACCURACY  =  : 0.9508
# error =  0.04923076923076919
# Sensivity = 0.9932432432432432
# Specificity = 0.9152542372881356
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       148
#            1       0.99      0.92      0.95       177
#
#     accuracy                           0.95       325
#    macro avg       0.95      0.95      0.95       325
# weighted avg       0.95      0.95      0.95       325
#
# Wall time: 427 ms

# %% [markdown]
# # Conclusion

# %% [markdown]
# By the comparison of models mentioned in the table we can discuss the model choise and its reason. From the perfomance the top ranked model is random forest which is showing precision  99% and recall of 92%. So we chose random forest to predict whether a testing transaction is fraudulent or authentic.
